# %%
import sys
import os

current_directory = os.getcwd()

project_directory = os.path.abspath(os.path.join(current_directory, '..'))
if project_directory not in sys.path:
    sys.path.append(project_directory)

import sanity_checks_methods
import couple_dirt_utils
import ML_algorithms
import pandas as pd

dataset_path = os.path.join(project_directory, 'dataset/stroke_data.csv')
df = pd.read_csv(dataset_path)

no_stroke_group = df[df['stroke'] == 0]
stroke_group = df[df['stroke'] == 1]

group_size = 5000

sampled_no_stroke_group = no_stroke_group.sample(n=group_size, random_state=42)
sampled_stroke_group = stroke_group.sample(n=group_size, random_state=42)

df = pd.concat([sampled_no_stroke_group,sampled_stroke_group])
df_to_test = df.copy()

df_to_test = sanity_checks_methods.drop_inconsistencies(df_to_test)
df = sanity_checks_methods.drop_inconsistencies(df)

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke(df,10)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
print('10-FOLD CROSS VALIDATION')
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')
# Out:
#  DECISION TREE PREDICTIONS AND RESULTS
# ---------------------------------------------------
# Classification Report on Training Set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96      3396
#            1       0.94      0.98      0.96      3262
#
#     accuracy                           0.96      6658
#    macro avg       0.96      0.96      0.96      6658
# weighted avg       0.96      0.96      0.96      6658
#
# Classification Report on Test Set - dirty:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92      1441
#            1       0.90      0.95      0.92      1413
#
#     accuracy                           0.92      2854
#    macro avg       0.92      0.92      0.92      2854
# weighted avg       0.92      0.92      0.92      2854
#
# Classification Report on Test Set - original:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      4837
#            1       0.95      0.99      0.97      4675
#
#     accuracy                           0.97      9512
#    macro avg       0.97      0.97      0.97      9512
# weighted avg       0.97      0.97      0.97      9512
#
#
# best hyperparameter: {'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'entropy'}
# hyperparameter's time search: 16.444849729537964 seconds
# training time needed: 0.032340288162231445 seconds
# Node Labels:
#  Annotation(0.643413, 0.984375, 'hypertension <= 0.5\nsamples = 6658\nvalue = [3396.0, 3262.0]\nclass = 0')
# AUC Score: 0.9888530368074081
# 10-FOLD CROSS VALIDATION
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Accuracy for each fold: [0.948948948948949, 0.9654654654654654, 0.96996996996997, 0.9564564564564565, 0.9774774774774775, 0.972972972972973, 0.9564564564564565, 0.972972972972973, 0.9578947368421052, 0.9759398496240601]
# Mean accuracy: 0.9654555307186886
# 95% confidence interval: (0.958384095917227, 0.9725269655201503)
# ORIGINAL VALUES RESTORED

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke(df,30)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')
# Out:
#  DECISION TREE PREDICTIONS AND RESULTS
# ---------------------------------------------------
# Classification Report on Training Set:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89      3396
#            1       0.89      0.90      0.89      3262
#
#     accuracy                           0.89      6658
#    macro avg       0.89      0.89      0.89      6658
# weighted avg       0.89      0.89      0.89      6658
#
# Classification Report on Test Set - dirty:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82      1441
#            1       0.81      0.84      0.83      1413
#
#     accuracy                           0.83      2854
#    macro avg       0.83      0.83      0.83      2854
# weighted avg       0.83      0.83      0.83      2854
#
# Classification Report on Test Set - original:
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93      4837
#            1       0.90      0.97      0.93      4675
#
#     accuracy                           0.93      9512
#    macro avg       0.93      0.93      0.93      9512
# weighted avg       0.93      0.93      0.93      9512
#
#
# best hyperparameter: {'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': None, 'max_depth': None, 'criterion': 'gini'}
# hyperparameter's time search: 16.216412782669067 seconds
# training time needed: 0.023365497589111328 seconds
# Node Labels:
#  Annotation(0.649634, 0.978261, 'hypertension <= 0.5\nsamples = 6658\nvalue = [3396.0, 3262.0]\nclass = 0')
# AUC Score: 0.9706177537453609
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Accuracy for each fold: [0.9174174174174174, 0.9159159159159159, 0.9234234234234234, 0.9384384384384384, 0.9204204204204204, 0.9414414414414415, 0.9234234234234234, 0.9384384384384384, 0.9007518796992481, 0.9097744360902256]
# Mean accuracy: 0.9229445234708393
# 95% confidence interval: (0.9134812308138974, 0.9324078161277812)
# ORIGINAL VALUES RESTORED

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke(df,50)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')
# Out:
#  DECISION TREE PREDICTIONS AND RESULTS
# ---------------------------------------------------
# Classification Report on Training Set:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      3396
#            1       0.85      0.84      0.84      3262
#
#     accuracy                           0.85      6658
#    macro avg       0.85      0.85      0.85      6658
# weighted avg       0.85      0.85      0.85      6658
#
# Classification Report on Test Set - dirty:
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72      1441
#            1       0.72      0.73      0.72      1413
#
#     accuracy                           0.72      2854
#    macro avg       0.72      0.72      0.72      2854
# weighted avg       0.72      0.72      0.72      2854
#
# Classification Report on Test Set - original:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      4837
#            1       0.85      0.88      0.87      4675
#
#     accuracy                           0.86      9512
#    macro avg       0.87      0.87      0.86      9512
# weighted avg       0.87      0.86      0.86      9512
#
#
# best hyperparameter: {'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'entropy'}
# hyperparameter's time search: 15.2522451877594 seconds
# training time needed: 0.02901601791381836 seconds
# Node Labels:
#  Annotation(0.683224, 0.987805, 'hypertension <= 0.5\nsamples = 6658\nvalue = [3396.0, 3262.0]\nclass = 0')
# AUC Score: 0.9243021539624927
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Accuracy for each fold: [0.7342342342342343, 0.7402402402402403, 0.7522522522522522, 0.7327327327327328, 0.7492492492492493, 0.6951951951951952, 0.7387387387387387, 0.7492492492492493, 0.7443609022556391, 0.7548872180451128]
# Mean accuracy: 0.7391140012192644
# 95% confidence interval: (0.7268407985599492, 0.7513872038785796)
# ORIGINAL VALUES RESTORED
