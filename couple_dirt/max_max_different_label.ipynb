# %%
import sys
import os

current_directory = os.getcwd()

project_directory = os.path.abspath(os.path.join(current_directory, '..'))
if project_directory not in sys.path:
    sys.path.append(project_directory)

import sanity_checks_methods
import couple_dirt_utils
import ML_algorithms
import pandas as pd

dataset_path = os.path.join(project_directory, 'dataset/stroke_data.csv')
df = pd.read_csv(dataset_path)

no_stroke_group = df[df['stroke'] == 0]
stroke_group = df[df['stroke'] == 1]

group_size = 5000

sampled_no_stroke_group = no_stroke_group.sample(n=group_size, random_state=42)
sampled_stroke_group = stroke_group.sample(n=group_size, random_state=42)

df = pd.concat([sampled_no_stroke_group,sampled_stroke_group])
df_to_test = df.copy()

df_to_test = sanity_checks_methods.drop_inconsistencies(df_to_test)
df = sanity_checks_methods.drop_inconsistencies(df)

# %% [markdown]
# adding new values on stroke = 1 label (10%)

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke_label(df,10,True)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
print('\n10-FOLD CROSS VALIDATION')
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')

# %% [markdown]
# adding 10 % to stroke = 0

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke_label(df,10,False)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
print('\n10-FOLD CROSS VALIDATION')
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')

# %% [markdown]
# adding 30% to stroke = 1

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke_label(df,30,True)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
print('\n10-FOLD CROSS VALIDATION')
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')
# Out:
#  DECISION TREE PREDICTIONS AND RESULTS
# ---------------------------------------------------
# Classification Report on Training Set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      3396
#            1       0.97      0.99      0.98      3262
#
#     accuracy                           0.98      6658
#    macro avg       0.98      0.98      0.98      6658
# weighted avg       0.98      0.98      0.98      6658
#
# Classification Report on Test Set - original:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      4837
#            1       0.96      0.98      0.97      4675
#
#     accuracy                           0.97      9512
#    macro avg       0.97      0.97      0.97      9512
# weighted avg       0.97      0.97      0.97      9512
#
#
# best hyperparameter: {'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'entropy'}
# hyperparameter's time search: 14.831738948822021 seconds
# training time needed: 0.02699875831604004 seconds
# Node Labels:
#  Annotation(0.815283, 0.980769, 'avg_glucose_level <= 249.3\nsamples = 6658\nvalue = [3396.0, 3262.0]\nclass = 0')
# AUC Score: 0.9908248472392509
#
# 10-FOLD CROSS VALIDATION
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Accuracy for each fold: [0.9684684684684685, 0.960960960960961, 0.960960960960961, 0.9564564564564565, 0.9624624624624625, 0.9744744744744744, 0.9624624624624625, 0.963963963963964, 0.9699248120300752, 0.9654135338345865]
# Mean accuracy: 0.9645548556074873
# 95% confidence interval: (0.9608315577797577, 0.968278153435217)
# ORIGINAL VALUES RESTORED

# %% [markdown]
# adding 30% to stroke = 0

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke_label(df,30,False)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
print('\n10-FOLD CROSS VALIDATION')
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')
# Out:
#  DECISION TREE PREDICTIONS AND RESULTS
# ---------------------------------------------------
# Classification Report on Training Set:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      3396
#            1       0.98      1.00      0.99      3262
#
#     accuracy                           0.99      6658
#    macro avg       0.99      0.99      0.99      6658
# weighted avg       0.99      0.99      0.99      6658
#
# Classification Report on Test Set - original:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      4837
#            1       0.95      0.99      0.97      4675
#
#     accuracy                           0.97      9512
#    macro avg       0.97      0.97      0.97      9512
# weighted avg       0.97      0.97      0.97      9512
#
#
# best hyperparameter: {'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'entropy'}
# hyperparameter's time search: 14.820485353469849 seconds
# training time needed: 0.023620128631591797 seconds
# Node Labels:
#  Annotation(0.793041, 0.982143, 'avg_glucose_level <= 249.655\nsamples = 6658\nvalue = [3396.0, 3262.0]\nclass = 0')
# AUC Score: 0.9870485639328748
#
# 10-FOLD CROSS VALIDATION
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Accuracy for each fold: [0.960960960960961, 0.948948948948949, 0.9564564564564565, 0.960960960960961, 0.9669669669669669, 0.9684684684684685, 0.9504504504504504, 0.9654654654654654, 0.9759398496240601, 0.9669172932330827]
# Mean accuracy: 0.962153582153582
# 95% confidence interval: (0.9561523639112002, 0.9681548003959639)
# ORIGINAL VALUES RESTORED

# %% [markdown]
# adding 50% to stroke = 1

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke_label(df,50,True)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
print('\n10-FOLD CROSS VALIDATION')
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')
# Out:
#  DECISION TREE PREDICTIONS AND RESULTS
# ---------------------------------------------------
# Classification Report on Training Set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      3396
#            1       0.96      0.98      0.97      3262
#
#     accuracy                           0.97      6658
#    macro avg       0.97      0.97      0.97      6658
# weighted avg       0.97      0.97      0.97      6658
#
# Classification Report on Test Set - original:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4837
#            1       0.94      0.94      0.94      4675
#
#     accuracy                           0.94      9512
#    macro avg       0.94      0.94      0.94      9512
# weighted avg       0.94      0.94      0.94      9512
#
#
# best hyperparameter: {'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'criterion': 'entropy'}
# hyperparameter's time search: 14.684614658355713 seconds
# training time needed: 0.021999597549438477 seconds
# Node Labels:
#  Annotation(0.842152, 0.981481, 'avg_glucose_level <= 249.3\nsamples = 6658\nvalue = [3396.0, 3262.0]\nclass = 0')
# AUC Score: 0.9860158161409545
#
# 10-FOLD CROSS VALIDATION
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Accuracy for each fold: [0.9414414414414415, 0.9669669669669669, 0.93993993993994, 0.963963963963964, 0.9594594594594594, 0.9564564564564565, 0.948948948948949, 0.9459459459459459, 0.9533834586466166, 0.9368421052631579]
# Mean accuracy: 0.9513348687032899
# 95% confidence interval: (0.9438976392693121, 0.9587720981372676)
# ORIGINAL VALUES RESTORED

# %% [markdown]
# adding 50% to stroke = 0

# %%
df, indices, original_vals = couple_dirt_utils.insert_high_values_for_stroke_label(df,50,False)

print('\n DECISION TREE PREDICTIONS AND RESULTS')
print('---------------------------------------------------')
decision_tree = ML_algorithms.train_decision_tree_model(df, df_to_test)
print('\n10-FOLD CROSS VALIDATION')
ML_algorithms.k_fold_cross_validation_dt(decision_tree,df_to_test)

df = couple_dirt_utils.restore_original_values(df,original_vals)
print('\nORIGINAL VALUES RESTORED')
# Out:
#  DECISION TREE PREDICTIONS AND RESULTS
# ---------------------------------------------------
# Classification Report on Training Set:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      3396
#            1       0.98      1.00      0.99      3262
#
#     accuracy                           0.99      6658
#    macro avg       0.99      0.99      0.99      6658
# weighted avg       0.99      0.99      0.99      6658
#
# Classification Report on Test Set - original:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96      4837
#            1       0.93      1.00      0.96      4675
#
#     accuracy                           0.96      9512
#    macro avg       0.96      0.96      0.96      9512
# weighted avg       0.97      0.96      0.96      9512
#
#
# best hyperparameter: {'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'entropy'}
# hyperparameter's time search: 14.322973489761353 seconds
# training time needed: 0.023003578186035156 seconds
# Node Labels:
#  Annotation(0.848568, 0.983871, 'avg_glucose_level <= 249.655\nsamples = 6658\nvalue = [3396.0, 3262.0]\nclass = 0')
# AUC Score: 0.9757353908541446
#
# 10-FOLD CROSS VALIDATION
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Accuracy for each fold: [0.9684684684684685, 0.96996996996997, 0.9414414414414415, 0.96996996996997, 0.9594594594594594, 0.9534534534534534, 0.9564564564564565, 0.960960960960961, 0.9593984962406015, 0.9639097744360903]
# Mean accuracy: 0.9603488450856871
# 95% confidence interval: (0.9541034134211059, 0.9665942767502682)
# ORIGINAL VALUES RESTORED
